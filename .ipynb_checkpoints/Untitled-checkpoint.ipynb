# %% [markdown]
# TODO:
# - Image size has an effect on tesseract performances
# - Train on custom font: https://pretius.com/how-to-prepare-training-files-for-tesseract-ocr-and-improve-characters-recognition/
# - bold and not bold, maybe more recent source ?
# - Alignment: PCA ?
# - Remove trailing dots : closing/opening not very efficient, maybe based on graident but would it be scale invariant ?
# - Remove T on the left: detect the mass of most letters ?
# - Recurrent issue of scale estimation.

# %%
import cv2
import pytesseract
from pathlib import Path
from tqdm.notebook import tqdm
import numpy as np
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt

# %%
SRC_PTS = np.array([(139,239), (370,238), (134,665), (397, 671)])*3*2

# %%
# img_texts = {}
# for img_path in tqdm(Path('data/receipt1').iterdir()):
#     img = cv2.imread(str(img_path))
#     img_texts[img_path.name] = pytesseract.image_to_string(img, config=custom_config)
#     break


# for img_name, img_text in img_texts.items():
#     print(img_name)
#     print(img_text)
#     print('\n --------- \n')
# Out:
# 0it [00:00, ?it/s]

# %%
def print_ocr(img, custom_config=r'-l fra --oem 3 --psm 6'):
    print(pytesseract.image_to_string(img, config=custom_config))

# %%
def get_boxes(img):
    img = img.copy()
    h, w = img.shape[:2]
    boxes = pytesseract.image_to_boxes(img) 
    for b in boxes.splitlines():
        b = b.split(' ')
        img = cv2.rectangle(img, (int(b[1]), h - int(b[2])), (int(b[3]), h - int(b[4])), (0, 255, 0), 2)
    return img

# %%
def show(imgs, scale=1, names=None):
    if names is None:
        names = map(str,range(len(imgs)))
    cv2.startWindowThread()
    for name, img in zip(names, imgs):
        cv2.imshow(name, resize(img, scale))
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# %%
def thresholding(image):
    return cv2.threshold(image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)[1]

def get_grayscale(image):
    return cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

def get_color(img):
    return cv2.cvtColor(img,cv2.COLOR_GRAY2RGB)

def blur(img, scale=5):
    return cv2.GaussianBlur(gray_img,(scale,scale),0)

def resize(img, scale):
    dsize = (np.array(img.shape)[:2]*scale).astype(int)
    return cv2.resize(img, (dsize[1], dsize[0]))

def to_bin(img, ksize=1):
    return thresholding(blur(img, ksize))

def close(img, s):
    kernel = np.ones((s,s),np.uint8)
    return cv2.morphologyEx(img, cv2.MORPH_OPEN, kernel)

# %%
def get_dst_pts(src_pts):
    a = src_pts[0]
    b = (src_pts[1][0], a[1])
    c = (a[0], src_pts[2][1])
    d = (b[0], c[1])
    return np.array([a,b,c,d])

def get_homography(img, src_pts):
    dst_pts = get_dst_pts(src_pts)
    src_pts, dst_pts = src_pts.astype(int), dst_pts.astype(int)
    return cv2.findHomography(src_pts, dst_pts)

# %%
def get_T_bounds(img):
    
    # TOOD: above th for n consec steps, or based on histogram
    vmass = img.sum(axis=0)
    border_th = (vmass.max() - vmass.min())/2
    vmin = np.argmax(vmass > border_th)
    vmax = len(vmass) - np.argmax(np.flip((vmass > border_th)))
    plt.plot(vmass)
    plt.show()
    
    img = img[:,vmin:vmax]
    vmass = vmass[vmin:vmax]
    plt.plot(vmass)
    plt.show()
    plt.hist(vmass, bins=40)
    plt.show()
    
    T_th1 = (vmass.max() - vmass.min())*0.99 + vmass.min()
    T_th2 = (vmass.max() - vmass.min())*0.93 + vmass.min()
    
    i_1 = np.argmax(vmass >T_th1)
    vmass = vmass[i_1:]
    plt.plot(vmass)
    plt.show()
    
    i_2 = np.argmax(vmass < T_th2)
    vmass = vmass[i_2:]
    plt.plot(vmass)
    plt.show()
    
    i_3 = np.argmax(vmass > T_th1)
    vmass = vmass[i_3:]
    plt.plot(vmass)
    plt.show()
    
    return vmin+i_1+i_2+i_3, vmax

# %%
def ticket_hom(img):
    # TODO improve by using all points with some stable regression
    h,w = img.shape
    lsrc_pts, rsrc_pts = [], []
    # TODO all in matrix operation
    for i in tqdm(range(h)):
        vmin = np.argmax(img[i])
        vmax = w - np.argmax(np.flip(img[i]))
        lsrc_pts.append([vmin, i])
        rsrc_pts.append([vmax, i])
    
    src_pts = np.vstack([lsrc_pts, rsrc_pts])
    dst_pts = np.vstack([np.zeros(h), range(h)])
    dst_pts = np.hstack([dst_pts, np.vstack([np.ones(h)*w, range(h)])]).T
    return src_pts, dst_pts

# %%
img = cv2.imread('data/receipt1/1a.jpg')
# full_scale = 0.25
# img = resize(img, full_scale)

gray_img = get_grayscale(img)
th_img = to_bin(gray_img)


src_pts, dst_pts = ticket_hom(th_img)
h, status = cv2.findHomography(src_pts, dst_pts)

hom_gray_img =  cv2.warpPerspective(gray_img, h, (gray_img.shape[1],gray_img.shape[0]))
hom_th_img =  cv2.warpPerspective(th_img, h, (th_img.shape[1],th_img.shape[0]))
show([th_img, hom_th_img], 0.2)

T_bounds = get_T_bounds(hom_th_img)
fin_th_img = hom_th_img[:, T_bounds[0]:T_bounds[1]]
fin_gray_img = hom_gray_img[:, T_bounds[0]:T_bounds[1]]
print_ocr(resize(fin_gray_img, 0.3))

show([fin_gray_img, fin_th_img], 0.2)
# Out:
#   0%|          | 0/4032 [00:00<?, ?it/s]
# MONOPRIX
# SAINT MICHEL
# 24 BD SAINT MICHEL,
# 75006 PARIS
# 01.44.32.05.00
# BONJOUR
# BOUCHERIE/TRAITEUR Se
# AIGUIL.PLT L.B.X06 6,20€
# ENTRETILEN/BAZAR. . . AO
# 2 X MPX EPONG GRATIV 1,59€ 3,16
# ENR 4 PILES MAX AA 6,07€
# EPICERIE /BOISSONS . BC
# 2 X NESCAFE SELECTIO 5,49€ 10,98€
# Le 2ème à moins 60% -3,29€
# CRAQUINETTES CHOCO 1,79€
# CRAQUINETTE FRAMB. 179€
# 2 X CRACOTTES FROMEN 1,49€ 2,98€
# 2è à -50% 360€
# 2 X EXCELLENCE NOIR 1,75€ 3,50€
# 150G IRISCOF LINDT 2,39€
# HARICOT ROUGE MPX 0,99€
# 2 X H.D'OLIVE V/EXTR"7,49€ 14,98€
# . Le 2ème à moins 50% -3,75€
# 2 X TAB CHOC.NR.FRUI 1,99€ 3,98€
# Le 2ème à moins 50% -1,00€
# MAILLE MOUT ORIG F 1,35€
# 30% de réduction im -0,41€
# FRUITS/BEGUMES, 2... 7
# CHAMP BLANC GEAN 4,99 kg 3 ge

# %%
class MonoprixParser():
    
    product_categories = [
        'BOUCHERIE/TRAITEUR', 
        'ENTRETIEN/BAZAR', 
        'EPICERIE /BOISSONS', 
        'FRUITS/LEGUMES',
    ] 
    
    def __init__(self):

    def parse_adress(self, lines):
        self.adress = {'ZIP code': lines[0], 'tel':''.join(lines[1].split('.'))}

    def parse_shop_name(self, lines):
        self.shop_names = {'brand': lines[0], 'name': lines[1]} 

    def parse_monoprix(lines):

# %%
inpt_img = close(th_img, 20)
edges = cv2.Canny(255-inpt_img, 50, 150,apertureSize = 3)
lines = cv2.HoughLines(edges,1,np.pi/180,200)

col_img = get_color(inpt_img)
for line in lines:
    rho,theta = line[0]
    a = np.cos(theta)
    b = np.sin(theta)
    x0 = a*rho
    y0 = b*rho
    x1 = int(x0 + 1000*(-b))
    y1 = int(y0 + 1000*(a))
    x2 = int(x0 - 1000*(-b))
    y2 = int(y0 - 1000*(a))
    cv2.line(col_img,(x1,y1),(x2,y2),(0,0,255),2)
show([col_img, inpt_img, edges], 0.5)

# %%
img = cv2.imread('data/receipt1/1a.jpg')
full_scale = 0.5
img = resize(img, full_scale)

gray_img = get_grayscale(img)
th_img = to_bin(gray_img)

src_pts = SRC_PTS * full_scale
h, status = get_homography(th_img, src_pts)
hom_gray_img =  cv2.warpPerspective(gray_img, h, (gray_img.shape[1],gray_img.shape[0]))
hom_th_img =  cv2.warpPerspective(th_img, h, (th_img.shape[1],th_img.shape[0]))
show([th_img, hom_th_img], 0.4)

T_bounds = get_T_bounds(hom_th_img)
fin_th_img = hom_th_img[:, T_bounds[0]:T_bounds[1]]
fin_gray_img = hom_gray_img[:, T_bounds[0]:T_bounds[1]]
show([fin_gray_img, img], 0.5)
# Out:
# [[28 31 28 ... 31 19 27]
#  [24 33 33 ... 32 33 31]
#  [37 36 27 ... 29 37 35]
#  ...
#  [54 65 54 ... 30 29 27]
#  [61 60 54 ... 31 31 27]
#  [54 48 58 ... 28 36 38]]
# Dst Pts
# [[ 417  717]
#  [1110  717]
#  [ 417 1995]
#  [1110 1995]]
# [[1]
#  [1]
#  [1]
#  [1]]

# %%
print(gray_img)
# Out:
# uint8

# %%
show([fin_gray_img, img], 0.5)

# %%
print_ocr(fin_th_img)
# Out:
# MONOPRIX
# SAINT MICHEL
# 24 BD SAINT MICHEL,
# 75006 PARIS
# 01.44,32,05,00
# BONJOUR
# ROUCHÉRLE/TRATTEUR.
# AÏGUIL.PLT L.B.X06 6,20€
# ENIRETLEN/BAZAR.
# 2 X MPX EPONG GRAT V 1,59€ 3,18€
# ENR 4 PILES MAX AA 6,07€
# EPICERIE/BOESSONS.........,...,.,,..
# 2 x NESCAFE SELECTIO 5,49€ 10,98€
# Le ?ème à moins 60% -3,29€
# CRAQUINETTES CHOCO 1,79€
# CRAQUINETTÉ FRAMB. 1,79€
# 2 x CRACOTTES FROMEN 1,49€ 2,96€
# ze à -50% -1,50€
# 2 X EXCELLENCE NOIR 1,75€ 3,50€
# 150G 1RISCOF LINDT 2,39€
# HARICOT ROUGE MPX 0,90€ |
# 2 X H.D'OLIVE V/EXTR 7,49€ 14,98€
# Le 2ème à moins 50% -3,75€
# 2 X TAB CHOC.NR.FRUI 1,99€ 3,98€
# Le 2ème à moins 50% -1,00€
# MAILLE MOUT ORIG F 1,95€
# 30% de réduction im -0,41€
# FRUITS/LEGUMES............,....,..,.
# CHAMP BLANC GEAN 4,98 €/kg 3,5

# %%
show([fin_th_img, th_img], 0.4)

# %%
show([fin_th_img, get_boxes(fin_th_img)])

# %%
def pca_rotate(bin_img):
    height, width = bin_img.shape
    center = (height-1)/2,(width-1)/2
    out = []
    for i in tqdm(range(height)):
        for j in range(width):
            if bin_img[i,j]:
                out.append((i-center[0],j-center[1]))
    img_pos = np.array(out, dtype=int)
    print('Fitting PCA')
    pca_fit = PCA(2).fit(img_pos)
    print('PCA fitted')
    x_h, x_w = pca_fit.components_ # Should have unit L2 norm
    if np.abs(x_h[0]) < np.abs(x_w[0]):
        x_h, x_w = x_w, x_h
    if x_h[0] < 0:
        x_h *= -1
    theta = np.arccos(x_h[0])
    print('Theta: ', theta)
    rot = cv2.getRotationMatrix2D(center, theta, 1)
    return cv2.warpAffine(bin_img, rot,(width, height))

rot_img = pca_rotate(th_img)
# Out:
#   0%|          | 0/4032 [00:00<?, ?it/s]
# Fitting PCA
# PCA fitted
# Theta:  0.026740960272945997
